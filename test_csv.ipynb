# %%
import numpy
import pandas

df = pandas.read_csv("res.csv", header=0)

print(df)

original_headers = list(df.columns.values)

df = df._get_numeric_data()

numeric_headers = list(df.columns.values)

numpy_array = df.as_matrix()
# Out:
#      CONFIG_BMP280_I2C CONFIG_COMEDI_DT3000 CONFIG_IRDA_CACHE_LAST_LSAP  \
# 0                    y                    n                           n
# 1                    n                    n                           n
# 2                    m                    n                           n
# 3                    y                    y                           n
# 4                    y                    n                           n
# 5                    n                    y                           y
# 6                    n                    n                           n
# 7                    n                    n                           n
# 8                    n                    n                           y
# 9                    n                    n                           n
# 10                   n                    n                           n
# 11                   y                    n                           n
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2a851eda2e88> in <module>()
# ----> 1 print(df)
#
# NameError: name 'df' is not defined
